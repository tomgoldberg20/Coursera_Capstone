# %% [markdown]
# # Capstone Clustering Lab

# %% [markdown]
# ### Part 1: Wrangling the Data

# %% [markdown]
# First I import Pandas:

# %%
import pandas as pd

# %% [markdown]
# Then, I create the dataframe by reading it in from the HTML file. I then use a loop to remove the unassigned codes.

# %%
#reading in the table to a dataframe
codes = pd.read_html('https://en.wikipedia.org/wiki/List_of_postal_codes_of_Canada:_M')[0]
#checking each postal code for assignment to a Borough, removing it if no Borough is listed
for i in range(180):
    if codes.loc[i,'Borough']=='Not assigned':
        codes.drop(i, axis=0, inplace=True)
codes
# Out:
#     Postal Code           Borough  \
# 2           M3A        North York
# 3           M4A        North York
# 4           M5A  Downtown Toronto
# 5           M6A        North York
# 6           M7A  Downtown Toronto
# ..          ...               ...
# 160         M8X         Etobicoke
# 165         M4Y  Downtown Toronto
# 168         M7Y      East Toronto
# 169         M8Y         Etobicoke
# 178         M8Z         Etobicoke
#
#                                          Neighbourhood
# 2                                            Parkwoods
# 3                                     Victoria Village
# 4                            Regent Park, Harbourfront
# 5                     Lawrence Manor, Lawrence Heights
# 6          Queen's Park, Ontario Provincial Government
# ..                                                 ...
# 160      The Kingsway, Montgomery Road, Old Mill North
# 165                               Church and Wellesley
# ...

# %% [markdown]
# Lastly, I need to reset the index, as the previous dataframe skips numbers in the index. As we can see, there are 103 total entries.

# %%
codes=codes.reset_index(drop=True) #'drop=True' prevents the previous index from becoming an additional column
codes
# Out:
#     Postal Code           Borough  \
# 0           M3A        North York
# 1           M4A        North York
# 2           M5A  Downtown Toronto
# 3           M6A        North York
# 4           M7A  Downtown Toronto
# ..          ...               ...
# 98          M8X         Etobicoke
# 99          M4Y  Downtown Toronto
# 100         M7Y      East Toronto
# 101         M8Y         Etobicoke
# 102         M8Z         Etobicoke
#
#                                          Neighbourhood
# 0                                            Parkwoods
# 1                                     Victoria Village
# 2                            Regent Park, Harbourfront
# 3                     Lawrence Manor, Lawrence Heights
# 4          Queen's Park, Ontario Provincial Government
# ..                                                 ...
# 98       The Kingsway, Montgomery Road, Old Mill North
# 99                                Church and Wellesley
# ...

# %% [markdown]
# ### Part 2: Incorporating the Coordinates

# %% [markdown]
# Now we need to collect information on their latitude and longitude coordinates. First, we create a dataframe from the provided CSV file:

# %%
all_coords=pd.read_csv('http://cocl.us/Geospatial_data')
all_coords
# Out:
#     Postal Code   Latitude  Longitude
# 0           M1B  43.806686 -79.194353
# 1           M1C  43.784535 -79.160497
# 2           M1E  43.763573 -79.188711
# 3           M1G  43.770992 -79.216917
# 4           M1H  43.773136 -79.239476
# ..          ...        ...        ...
# 98          M9N  43.706876 -79.518188
# 99          M9P  43.696319 -79.532242
# 100         M9R  43.688905 -79.554724
# 101         M9V  43.739416 -79.588437
# 102         M9W  43.706748 -79.594054
#
# [103 rows x 3 columns]

# %% [markdown]
# Again, there are 103 total entries, except this time they are grouped by number rather than by last letter. Since they are in different orders, we must match each coordinate pair to its respective code in the other dataframe. To do this, we can use nested loops. First we must add new columns in the old dataframe that are to be filled.

# %%
import numpy as np
lat=np.zeros(103).tolist()
long=np.zeros(103).tolist()
type(lat) #this ensures that we have lists of zeros to add into our dataframe.
# Out:
# list

# %%
codes['Latitude']=lat
codes['Longitude']=long
codes # The zeros will be replaced in this dataframe shortly.
# Out:
#     Postal Code           Borough  \
# 0           M3A        North York
# 1           M4A        North York
# 2           M5A  Downtown Toronto
# 3           M6A        North York
# 4           M7A  Downtown Toronto
# ..          ...               ...
# 98          M8X         Etobicoke
# 99          M4Y  Downtown Toronto
# 100         M7Y      East Toronto
# 101         M8Y         Etobicoke
# 102         M8Z         Etobicoke
#
#                                          Neighbourhood  Latitude  Longitude
# 0                                            Parkwoods       0.0        0.0
# 1                                     Victoria Village       0.0        0.0
# 2                            Regent Park, Harbourfront       0.0        0.0
# 3                     Lawrence Manor, Lawrence Heights       0.0        0.0
# 4          Queen's Park, Ontario Provincial Government       0.0        0.0
# ..                                                 ...       ...        ...
# ...

# %%
for i in range(103):
    code=all_coords.loc[i,'Postal Code']
    la=all_coords.loc[i,'Latitude']
    lg=all_coords.loc[i,'Longitude']
    
    for j in range(103):
        if (codes.loc[j,'Postal Code']==code):
            codes.loc[j,'Latitude']=la
            codes.loc[j,'Longitude']=lg
            
codes
# Out:
#     Postal Code           Borough  \
# 0           M3A        North York
# 1           M4A        North York
# 2           M5A  Downtown Toronto
# 3           M6A        North York
# 4           M7A  Downtown Toronto
# ..          ...               ...
# 98          M8X         Etobicoke
# 99          M4Y  Downtown Toronto
# 100         M7Y      East Toronto
# 101         M8Y         Etobicoke
# 102         M8Z         Etobicoke
#
#                                          Neighbourhood   Latitude  Longitude
# 0                                            Parkwoods  43.753259 -79.329656
# 1                                     Victoria Village  43.725882 -79.315572
# 2                            Regent Park, Harbourfront  43.654260 -79.360636
# 3                     Lawrence Manor, Lawrence Heights  43.718518 -79.464763
# 4          Queen's Park, Ontario Provincial Government  43.662301 -79.389494
# ..                                                 ...        ...        ...
# ...

# %% [markdown]
# ### Part 3: Analysis

# %% [markdown]
# Now we need to visually display the postal codes on the map. First we import the folium library and initialize the map of Toronto.

# %%
import folium

# %%
toronto = folium.Map(location=[43.70,-79.40],zoom_start=10.5)

# %% [markdown]
# The following cell creates popups on our map so that we can see where our zip codes actually are.

# %%
for lat, lng, label_a in zip(codes['Latitude'], codes['Longitude'], codes['Postal Code']):
    label_a = folium.Popup(label_a, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label_a,
        color='blue',
        fill=True,
        fill_color='#3186cc',
        fill_opacity=0.7,
        parse_html=False).add_to(toronto)

# %% [markdown]
# Here we can see that the postal codes get more dense near the center of the city, and more scattered as they get farther from this point. Given that the M5 codes are the more densely clustered ones and that this area is likely the most densely populated, these codes may be assigned in order to keep the number of people living in a given postal code down. Apart from relocating people (which is morally and legally questionable for many reasons), the best option would be to split the postal codes up.

# %%
import requests
import json
LIMIT=100
radius=1000
CLIENT_ID='EMR3V1CKO53I13SPOLH0QST0OMK4PBXWNMR34GNBRPKANP4E'
CLIENT_SECRET='T2FRSH24PI4IJSTWDTPEWU5DXM2FEH5VE32RXMOPFN5YYGXI'
VERSION='20200810'



def getNearbyVenues(names, latitudes, longitudes, radius):
    venues_list=[]
    for name, lat, lng in zip(names, latitudes, longitudes):
        url = 'https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}'.format(
            CLIENT_ID, 
            CLIENT_SECRET, 
            VERSION, 
            lat, 
            lng, 
            radius, 
            LIMIT)
        results = requests.get(url).json()["response"]['groups'][0]['items']
        venues_list.append([(
            name, 
            lat, 
            lng, 
            v['venue']['name'], 
            v['venue']['location']['lat'], 
            v['venue']['location']['lng'],  
            v['venue']['categories'][0]['name']) for v in results])
    nearby_venues = pd.DataFrame([item for venue_list in venues_list for item in venue_list])
    nearby_venues.columns = ['Neighborhood', 
                  'Neighborhood Latitude', 
                  'Neighborhood Longitude', 
                  'Venue', 
                  'Venue Latitude', 
                  'Venue Longitude', 
                  'Venue Category']
    return(nearby_venues)

# %%
toronto_venues = getNearbyVenues(names=codes['Neighbourhood'],
                                   latitudes=codes['Latitude'],
                                   longitudes=codes['Longitude'],radius=1000
                                  )

# %%
toronto_venues
# Out:
#                                            Neighborhood  \
# 0                                             Parkwoods
# 1                                             Parkwoods
# 2                                             Parkwoods
# 3                                             Parkwoods
# 4                                             Parkwoods
# ...                                                 ...
# 4880  Mimico NW, The Queensway West, South of Bloor,...
# 4881  Mimico NW, The Queensway West, South of Bloor,...
# 4882  Mimico NW, The Queensway West, South of Bloor,...
# 4883  Mimico NW, The Queensway West, South of Bloor,...
# 4884  Mimico NW, The Queensway West, South of Bloor,...
#
#       Neighborhood Latitude  Neighborhood Longitude                   Venue  \
# 0                 43.753259              -79.329656         Allwyn's Bakery
# 1                 43.753259              -79.329656         Brookbanks Park
# ...

# %% [markdown]
# With the radius being set to 1000m, I worried that there may be some overlap in venues collected if they were within 1000m of two different zip codes. I saw this as an acceptable risk over potentially missing out on venues in our search.

# %% [markdown]
# Now I seek to display all of the gyms in Toronto as red dots, with their names popping up as their labels.

# %%
for i in range(4885):
    if toronto_venues.loc[i,'Venue Category']=='Gym':
        lat=toronto_venues.loc[i,'Venue Latitude']
        lng=toronto_venues.loc[i,'Venue Longitude']
        label = folium.Popup(toronto_venues.loc[i,'Venue'], parse_html=True)
        folium.CircleMarker(
            [lat, lng],
            radius=1,
            popup=label,
            color='red',
            fill=True,
            fill_color='orange',
            fill_opacity=0.7,
            parse_html=False).add_to(toronto)

# %%
toronto
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# We can see that the gyms are clustered in roughly the same way that the zip codes are, if not more so. Let's see if this is true with coffee shops as well. For this we will plot them in green.

# %%
for i in range(4885):
    if toronto_venues.loc[i,'Venue Category']=='Coffee Shop':
        lat=toronto_venues.loc[i,'Venue Latitude']
        lng=toronto_venues.loc[i,'Venue Longitude']
        label = folium.Popup(toronto_venues.loc[i,'Venue'], parse_html=True)
        folium.CircleMarker(
            [lat, lng],
            radius=1,
            popup=label,
            color='green',
            fill=True,
            fill_color='green',
            fill_opacity=0.7,
            parse_html=False).add_to(toronto)

# %%
toronto
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
